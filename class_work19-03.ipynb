# %%
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
pio.renderers.default='notebook'
import networkx as nx

# %%
df=pd.DataFrame({'dep':['hr','it','hr','it','hr'],
                'age':[20,25,30,22,10],
                'sal':[100,500,200,300,100],
                'sex':['f','m','m','f','f']})

# %%
df
# Out:
#   dep  age  sal sex
# 0  hr   20  100   f
# 1  it   25  500   m
# 2  hr   30  200   m
# 3  it   22  300   f
# 4  hr   10  100   f

# %%
px.histogram(data_frame=df,y='age',color=df.sex,nbins=50,pattern_shape=df.dep)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
px.histogram(data_frame=df,x=df.dep,y=df.sal,color=df.sex)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotly\io\_renderers.py:51: UserWarning: Plotly version >= 6 requires Jupyter Notebook >= 7 but you have 6.1.4 installed.
#  To upgrade Jupyter Notebook, please run `pip install notebook --upgrade`.
#   warnings.warn(
# ...

# %%
G=nx.DiGraph()
G.add_node(1)
G.add_node(2)
G.add_node(3)
G.add_node(4)
G.add_edge(1,2)
G.add_edge(2,3)
G.add_edge(3,4)
G.add_edge(4,1)
nx.draw(G,with_labels=True,node_color='green',node_size=10000)

# %%
G=nx.DiGraph()
G.add_nodes_from([1,2,3,4])
G.add_edges_from([(1,2),(2,3),(3,4),(4,1)])
nx.draw(G,with_labels=True)

# %%
def birthday():
    print('happy bday jyoti')
    print('!!!!$!!!!!!!!!$!')
    print('happy bday mascara')
birthday()
# Out:
# happy bday jyoti
# !!!!$!!!!!!!!!$!
# happy bday mascara
