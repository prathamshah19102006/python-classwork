# %%
import numpy as np
import pandas as pd
ds=pd.read_csv('train.csv')
ds.head()
ds.describe(exclude="integer")

# %%
ds.dropna()

# %%
df=pd.DataFrame([[1,np.nan,3,4],[2,4,np.nan,8],[np.nan,4,5,9],[np.nan,1,np.nan,3],[np.nan,np.nan,np.nan,np.nan]],columns=["a","b","c","d"])
df
df.loc[5]=[1,2,3,4]
df
# df.dropna(how='all')

# %%
df.dropna(how='all',subset=['b','d'])

# %%
df.dropna(thresh=2)

# %%
df.dropna(thresh=3)

# %%
df['a']=df['a'].fillna(df['a'].mean())

# %%
df
