# %%
import pandas as pd
import numpy as np

# %%
ds=pd.read_csv('train.csv')
print(ds)
ds.index
ds.columns
ds.shape
ds.size
ds.values
ds.ndim
ds.dtypes
ds[['Pclass','Age']]
ds[(ds['Age']>18)&(ds['Sex']=='male')]
ds[(ds['Survived']==1)&(ds['Sex']=='female')]
ds[(ds['Survived']==1)&(ds['Sex']=='male')]
ds.iloc[2,2]
ds.iloc[2,3]
ds.iloc[2]
ds.iloc[:10,3:9]
ds.iloc[2,2]

# %%
ds=pd.DataFrame({'sub':['python','fsd','coa','toc','dm'],'fac':['vha','psp','vby','dps','mss'],'mark':[10,9,10,9,9]})
ds=ds.set_index('sub',drop=True)
ds.loc['fsd','fac']
ds.loc['fsd','fac']='nas'
ds.loc['project']=['vha',10]
ds['new']=ds['mark']*10
ds

# %%
ds=pd.read_csv('train.csv')
# ds=ds.set_index('Name')
# ds.loc['Braund, Mr. Owen Harris']
# ds.loc['Braund, Mr. Owen Harris':'Allen, Mr. William Henry','Sex':'Ticket']
# ds['child']=ds['Parch']+ds['SibSp']
ds.head()
ds.tail()
ds.sample(7)
ds.info()
ds.describe(include='object')

# %%
df=pd.DataFrame({'Courseid':[1,2,3,4,5],'coursename':['python','fsd','coa','toc','dm'],'credits':[6,5,4,6,12],'faculty':['vha','psp','vby','dps','mss']})
df
df=df.set_index('Courseid',drop=True)
df['semester']=1
df.iloc[2,1]=15
df
df.loc['6']=['etc',11,'vha',1]
df
# Out:
#          coursename  credits faculty  semester
# Courseid
# 1            python        6     vha         1
# 2               fsd        5     psp         1
# 3               coa       15     vby         1
# 4               toc        6     dps         1
# 5                dm       12     mss         1
# 6               etc       11     vha         1

# %%
l=np.random.randint(1,100,[8,5])
df=pd.DataFrame(l,columns=['a','b','c','d','e'])
df.shape
df.size
df['sum']=df['a']+df['b']+df['c']+df['d']+df['e']
df.iloc[6,2]=7
df.loc[2:7,'b':'d']
df.loc[8]=[50,70,80,90,100,100]
df
# Out:
#     a   b   c   d    e  sum
# 0  11  39   5  10   84  149
# 1  81  98  58  94   42  373
# 2  27  48   6  61    7  149
# 3  43  95  38  94   35  305
# 4  40  97  92  19   89  337
# 5  63  71  83  83   92  392
# 6  92  59   7  70   40  334
# 7   1  13  46  86   53  199
# 8  50  70  80  90  100  100
